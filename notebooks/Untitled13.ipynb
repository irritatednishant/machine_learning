# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
import mglearn as mg
x,y = mg.datasets.make_wave()
plt.plot(x,y,"v")
plt.plot(x,y,"o",label='circle')
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import mglearn as mg
#       5 x,y = mg.datasets.make_wave()
#       6 plt.plot(x,y,"v")
#
# ModuleNotFoundError: No module named 'mglearn'

# %%
pip install mglearn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting mglearn
#   Downloading mglearn-0.2.0-py2.py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: numpy in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (3.10.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from mglearn) (1.5.1)
# Requirement already satisfied: pandas in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (2.3.0)
# Requirement already satisfied: pillow in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (11.2.1)
# Requirement already satisfied: cycler in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (0.12.1)
# Requirement already satisfied: imageio in c:\programdata\anaconda3\lib\site-packages (from mglearn) (2.33.1)
# Requirement already satisfied: joblib in c:\users\pc\appdata\roaming\python\python312\site-packages (from mglearn) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib->mglearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from pandas->mglearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\appdata\roaming\python\python312\site-packages (from pandas->mglearn) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from scikit-learn->mglearn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->mglearn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.17.0)
# Downloading mglearn-0.2.0-py2.py3-none-any.whl (581 kB)
#    ---------------------------------------- 0.0/581.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/581.4 kB ? eta -:--:--
#    ---------------------------------------- 581.4/581.4 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: mglearn
# Successfully installed mglearn-0.2.0
