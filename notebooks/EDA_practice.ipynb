# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips,x='total_bill',y="tip",hue= "sex",style="day",size="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df = pd.read_csv("Vehicle Price.csv")

# %%
df.sample(5)
# Out:
#                                  name  \
# 386                2024 Ford Edge SEL
# 237        2024 Dodge Hornet R/T Plus
# 646          2024 Dodge Hornet GT AWD
# 470  2024 Jeep Grand Cherokee Limited
# 457    2024 Jeep Compass Latitude Lux
#
#                                            description   make           model  \
# 386                                                NaN   Ford            Edge
# 237  \n      \n        WE ACCEPT ALL MAKE AND MODEL...  Dodge          Hornet
# 646  \n      \n        New Price! 8 Ball 2024 Dodge...  Dodge          Hornet
# 470  \n      \n        Check out this great low mil...   Jeep  Grand Cherokee
# 457  \n      \n        2024 Jeep Compass Latitude L...   Jeep         Compass
#
#      year    price                                             engine  \
# 386  2024  44615.0  t 2L I-4 gasoline direct injection, DOHC, vari...
# 237  2024  51835.0                          16V GDI DOHC Turbo Hybrid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   year            1002 non-null   int64
#  5   price           979 non-null    float64
#  6   engine          1000 non-null   object
#  7   cylinders       897 non-null    float64
#  8   fuel            995 non-null    object
#  9   mileage         968 non-null    float64
#  10  transmission    1000 non-null   object
#  11  trim            1001 non-null   object
#  12  body            999 non-null    object
#  13  doors           995 non-null    float64
#  14  exterior_color  997 non-null    object
#  15  interior_color  964 non-null    object
#  16  drivetrain      1002 non-null   object
# ...

# %%
df["doors"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='doors'>

# %%
plt.hist(data=df,x="price",bins=30)
# Out:
# (array([  1.,   0.,   1.,  37., 108., 153., 139., 181., 109.,  80.,  47.,
#          41.,  30.,  26.,   9.,   3.,   6.,   4.,   1.,   1.,   0.,   0.,
#           0.,   1.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([     0.        ,   6529.83333333,  13059.66666667,  19589.5       ,
#          26119.33333333,  32649.16666667,  39179.        ,  45708.83333333,
#          52238.66666667,  58768.5       ,  65298.33333333,  71828.16666667,
#          78358.        ,  84887.83333333,  91417.66666667,  97947.5       ,
#         104477.33333333, 111007.16666667, 117537.        , 124066.83333333,
#         130596.66666667, 137126.5       , 143656.33333333, 150186.16666667,
#         156716.        , 163245.83333333, 169775.66666667, 176305.5       ,
#         182835.33333333, 189365.16666667, 195895.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.boxplot(data=df,x="price")
# Out:
# <Axes: xlabel='price'>

# %%
df.head(3)
# Out:
#                               name  \
# 0     2024 Jeep Wagoneer Series II
# 1  2024 Jeep Grand Cherokee Laredo
# 2         2024 GMC Yukon XL Denali
#
#                                          description  make           model  \
# 0  \n      \n        Heated Leather Seats, Nav Sy...  Jeep        Wagoneer
# 1  Al West is committed to offering every custome...  Jeep  Grand Cherokee
# 2                                                NaN   GMC        Yukon XL
#
#    year    price                                             engine  \
# 0  2024  74600.0                            24V GDI DOHC Twin Turbo
# 1  2024  50170.0                                                OHV
# 2  2024  96410.0  6.2L V-8 gasoline direct injection, variable v...
#
#    cylinders      fuel  mileage       transmission       trim body  doors  \
# 0        6.0  Gasoline     10.0  8-Speed Automatic  Series II  SUV    4.0
# 1        6.0  Gasoline      1.0  8-Speed Automatic     Laredo  SUV    4.0
# ...

# %%
sns.scatterplot(data=df,x="mileage", y="price")
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
print(df["mileage"].max().astype(int))
# Out:
# 9711.0
